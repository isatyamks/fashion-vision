# %%
from ultralytics import YOLO
import cv2
from PIL import Image
import os

# %%
Per_model = YOLO("../../data_20/runs/detect/fashion-v12/weights/best.pt")

# %%
model = Per_model

# %%
names = model.names
names
# Out:
# {0: 'Casual_Jeans',
#  1: 'Casual_Sneakers',
#  2: 'Casual_Top',
#  3: 'Corporate_Gown',
#  4: 'Corporate_Shoe',
#  5: 'Corporate_Skirt',
#  6: 'Corporate_Top',
#  7: 'Corporate_Trouser',
#  8: 'Native',
#  9: 'Shorts',
#  10: 'Suits',
#  11: 'Tie'}

# %%
conf_threshold = 0.6

# %%
output_dir = "../video_crops"
os.makedirs(output_dir, exist_ok=True)

# %%
video_path = "../data/videos/2025-05-31_14-01-37_UTC.mp4"
cap = cv2.VideoCapture(video_path)

# %%
frame_count = 0

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    pil_image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    results = model(frame)[0]
    print(results.boxes)  # Print raw output
    print(results.boxes.xyxy)  # Bounding boxes
    print(results.boxes.conf)  # Confidence scores
    print(results.boxes.cls)   # Class indices

    for i, (box, conf, cls) in enumerate(zip(results.boxes.xyxy, results.boxes.conf, results.boxes.cls)):
        if conf < conf_threshold:
            continue
        x1, y1, x2, y2 = map(int, box)
        cropped = pil_image.crop((x1, y1, x2, y2))
        class_id = int(cls.item())
        class_name = names[class_id]
        crop_filename = f"{output_dir}/frame{frame_count}_obj{i}_{class_name}_conf{conf:.2f}.jpg"
        cropped.save(crop_filename)
        print(f"Saved: {crop_filename}")

    frame_count += 1

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 Corporate_Gown, 167.8ms
# Speed: 13.4ms preprocess, 167.8ms inference, 437.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.4344], device='cuda:0')
# data: tensor([[2.2222e+02, 4.2063e+02, 6.2622e+02, 1.2783e+03, 4.3443e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[424.2194, 849.4574, 404.0028, 857.6545]], device='cuda:0')
# xywhn: tensor([[0.5892, 0.6636, 0.5611, 0.6700]], device='cuda:0')
# xyxy: tensor([[ 222.2180,  420.6301,  626.2208, 1278.2847]], device='cuda:0')
# xyxyn: tensor([[0.3086, 0.3286, 0.8698, 0.9987]], device='cuda:0')
# tensor([[ 222.2180,  420.6301,  626.2208, 1278.2847]], device='cuda:0')
# tensor([0.4344], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Gown, 17.3ms
# Speed: 2.9ms preprocess, 17.3ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.4025], device='cuda:0')
# data: tensor([[2.0620e+02, 4.0324e+02, 6.6075e+02, 1.2790e+03, 4.0250e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[433.4747, 841.1335, 454.5416, 875.7781]], device='cuda:0')
# xywhn: tensor([[0.6020, 0.6571, 0.6313, 0.6842]], device='cuda:0')
# xyxy: tensor([[ 206.2039,  403.2445,  660.7455, 1279.0226]], device='cuda:0')
# xyxyn: tensor([[0.2864, 0.3150, 0.9177, 0.9992]], device='cuda:0')
# tensor([[ 206.2039,  403.2445,  660.7455, 1279.0226]], device='cuda:0')
# tensor([0.4025], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Gown, 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.3840], device='cuda:0')
# data: tensor([[2.0171e+02, 3.7591e+02, 6.5567e+02, 1.2789e+03, 3.8404e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[428.6924, 827.3911, 453.9605, 902.9552]], device='cuda:0')
# xywhn: tensor([[0.5954, 0.6464, 0.6305, 0.7054]], device='cuda:0')
# xyxy: tensor([[ 201.7121,  375.9135,  655.6726, 1278.8687]], device='cuda:0')
# xyxyn: tensor([[0.2802, 0.2937, 0.9107, 0.9991]], device='cuda:0')
# tensor([[ 201.7121,  375.9135,  655.6726, 1278.8687]], device='cuda:0')
# tensor([0.3840], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Gown, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.3052], device='cuda:0')
# data: tensor([[2.0873e+02, 3.7572e+02, 6.6161e+02, 1.2772e+03, 3.0521e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[435.1718, 826.4519, 452.8739, 901.4648]], device='cuda:0')
# xywhn: tensor([[0.6044, 0.6457, 0.6290, 0.7043]], device='cuda:0')
# xyxy: tensor([[ 208.7349,  375.7195,  661.6088, 1277.1843]], device='cuda:0')
# xyxyn: tensor([[0.2899, 0.2935, 0.9189, 0.9978]], device='cuda:0')
# tensor([[ 208.7349,  375.7195,  661.6088, 1277.1843]], device='cuda:0')
# tensor([0.3052], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Gown, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.3040], device='cuda:0')
# data: tensor([[1.6939e+02, 3.2906e+02, 6.6096e+02, 1.2763e+03, 3.0397e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[415.1758, 802.6779, 491.5654, 947.2306]], device='cuda:0')
# xywhn: tensor([[0.5766, 0.6271, 0.6827, 0.7400]], device='cuda:0')
# xyxy: tensor([[ 169.3931,  329.0626,  660.9585, 1276.2932]], device='cuda:0')
# xyxyn: tensor([[0.2353, 0.2571, 0.9180, 0.9971]], device='cuda:0')
# tensor([[ 169.3931,  329.0626,  660.9585, 1276.2932]], device='cuda:0')
# tensor([0.3040], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Gown, 17.0ms
# Speed: 1.3ms preprocess, 17.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.2594], device='cuda:0')
# data: tensor([[8.8262e+01, 3.0892e+02, 6.5747e+02, 1.2791e+03, 2.5939e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[372.8637, 794.0080, 569.2042, 970.1859]], device='cuda:0')
# xywhn: tensor([[0.5179, 0.6203, 0.7906, 0.7580]], device='cuda:0')
# xyxy: tensor([[  88.2616,  308.9150,  657.4658, 1279.1010]], device='cuda:0')
# xyxyn: tensor([[0.1226, 0.2413, 0.9131, 0.9993]], device='cuda:0')
# tensor([[  88.2616,  308.9150,  657.4658, 1279.1010]], device='cuda:0')
# tensor([0.2594], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Gown, 17.0ms
# Speed: 1.3ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.3729], device='cuda:0')
# data: tensor([[7.8223e+01, 2.9842e+02, 6.5038e+02, 1.2794e+03, 3.7287e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[364.3035, 788.8969, 572.1613, 980.9548]], device='cuda:0')
# xywhn: tensor([[0.5060, 0.6163, 0.7947, 0.7664]], device='cuda:0')
# xyxy: tensor([[  78.2228,  298.4194,  650.3842, 1279.3743]], device='cuda:0')
# xyxyn: tensor([[0.1086, 0.2331, 0.9033, 0.9995]], device='cuda:0')
# tensor([[  78.2228,  298.4194,  650.3842, 1279.3743]], device='cuda:0')
# tensor([0.3729], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 (no detections), 17.1ms
# Speed: 1.3ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 1 Corporate_Gown, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.3142], device='cuda:0')
# data: tensor([[3.6734e+01, 1.8035e+02, 6.4880e+02, 1.2782e+03, 3.1423e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 342.7692,  729.2844,  612.0704, 1097.8762]], device='cuda:0')
# xywhn: tensor([[0.4761, 0.5698, 0.8501, 0.8577]], device='cuda:0')
# xyxy: tensor([[  36.7340,  180.3463,  648.8044, 1278.2225]], device='cuda:0')
# xyxyn: tensor([[0.0510, 0.1409, 0.9011, 0.9986]], device='cuda:0')
# tensor([[  36.7340,  180.3463,  648.8044, 1278.2225]], device='cuda:0')
# tensor([0.3142], device='cuda:0')
# tensor([3.], device='cuda:0')
#
# 0: 640x384 (no detections), 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 (no detections), 16.3ms
# Speed: 1.7ms preprocess, 16.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 (no detections), 16.3ms
# Speed: 1.3ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 (no detections), 16.4ms
# Speed: 1.3ms preprocess, 16.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 (no detections), 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 (no detections), 16.2ms
# Speed: 1.4ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 (no detections), 17.5ms
# Speed: 1.3ms preprocess, 17.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.2816], device='cuda:0')
# data: tensor([[2.9689e+02, 1.0030e+03, 5.1089e+02, 1.2791e+03, 2.8162e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 403.8859, 1141.0398,  213.9985,  276.1384]], device='cuda:0')
# xywhn: tensor([[0.5610, 0.8914, 0.2972, 0.2157]], device='cuda:0')
# xyxy: tensor([[ 296.8866, 1002.9706,  510.8851, 1279.1090]], device='cuda:0')
# xyxyn: tensor([[0.4123, 0.7836, 0.7096, 0.9993]], device='cuda:0')
# tensor([[ 296.8866, 1002.9706,  510.8851, 1279.1090]], device='cuda:0')
# tensor([0.2816], device='cuda:0')
# tensor([1.], device='cuda:0')
#
# 0: 640x384 (no detections), 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([], device='cuda:0')
# conf: tensor([], device='cuda:0')
# data: tensor([], device='cuda:0', size=(0, 6))
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([0, 6])
# xywh: tensor([], device='cuda:0', size=(0, 4))
# xywhn: tensor([], device='cuda:0', size=(0, 4))
# xyxy: tensor([], device='cuda:0', size=(0, 4))
# xyxyn: tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0', size=(0, 4))
# tensor([], device='cuda:0')
# tensor([], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 14.6ms
# Speed: 1.2ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.4204], device='cuda:0')
# data: tensor([[2.8879e+02, 1.0316e+03, 4.9135e+02, 1.2792e+03, 4.2037e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 390.0707, 1155.3582,  202.5673,  247.5952]], device='cuda:0')
# xywhn: tensor([[0.5418, 0.9026, 0.2813, 0.1934]], device='cuda:0')
# xyxy: tensor([[ 288.7870, 1031.5605,  491.3544, 1279.1558]], device='cuda:0')
# xyxyn: tensor([[0.4011, 0.8059, 0.6824, 0.9993]], device='cuda:0')
# tensor([[ 288.7870, 1031.5605,  491.3544, 1279.1558]], device='cuda:0')
# tensor([0.4204], device='cuda:0')
# tensor([1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 14.7ms
# Speed: 1.3ms preprocess, 14.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.4525], device='cuda:0')
# data: tensor([[2.8221e+02, 1.0391e+03, 4.8989e+02, 1.2783e+03, 4.5247e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 386.0518, 1158.7249,  207.6797,  239.2124]], device='cuda:0')
# xywhn: tensor([[0.5362, 0.9053, 0.2884, 0.1869]], device='cuda:0')
# xyxy: tensor([[ 282.2120, 1039.1187,  489.8917, 1278.3311]], device='cuda:0')
# xyxyn: tensor([[0.3920, 0.8118, 0.6804, 0.9987]], device='cuda:0')
# tensor([[ 282.2120, 1039.1187,  489.8917, 1278.3311]], device='cuda:0')
# tensor([0.4525], device='cuda:0')
# tensor([1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.5280], device='cuda:0')
# data: tensor([[2.6749e+02, 1.0514e+03, 4.9329e+02, 1.2798e+03, 5.2796e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 380.3876, 1165.5979,  225.8043,  228.3086]], device='cuda:0')
# xywhn: tensor([[0.5283, 0.9106, 0.3136, 0.1784]], device='cuda:0')
# xyxy: tensor([[ 267.4855, 1051.4436,  493.2898, 1279.7522]], device='cuda:0')
# xyxyn: tensor([[0.3715, 0.8214, 0.6851, 0.9998]], device='cuda:0')
# tensor([[ 267.4855, 1051.4436,  493.2898, 1279.7522]], device='cuda:0')
# tensor([0.5280], device='cuda:0')
# tensor([1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 15.4ms
# Speed: 1.4ms preprocess, 15.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.3624], device='cuda:0')
# data: tensor([[2.5272e+02, 1.0658e+03, 4.9751e+02, 1.2793e+03, 3.6238e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 375.1139, 1172.5500,  244.7885,  213.4556]], device='cuda:0')
# xywhn: tensor([[0.5210, 0.9161, 0.3400, 0.1668]], device='cuda:0')
# xyxy: tensor([[ 252.7197, 1065.8223,  497.5081, 1279.2778]], device='cuda:0')
# xyxyn: tensor([[0.3510, 0.8327, 0.6910, 0.9994]], device='cuda:0')
# tensor([[ 252.7197, 1065.8223,  497.5081, 1279.2778]], device='cuda:0')
# tensor([0.3624], device='cuda:0')
# tensor([1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Top, 14.6ms
# Speed: 1.4ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.2501], device='cuda:0')
# data: tensor([[1.4225e+01, 3.5614e+01, 6.9639e+02, 7.2922e+02, 2.5014e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[355.3056, 382.4183, 682.1603, 693.6089]], device='cuda:0')
# xywhn: tensor([[0.4935, 0.2988, 0.9474, 0.5419]], device='cuda:0')
# xyxy: tensor([[ 14.2255,  35.6139, 696.3857, 729.2228]], device='cuda:0')
# xyxyn: tensor([[0.0198, 0.0278, 0.9672, 0.5697]], device='cuda:0')
# tensor([[ 14.2255,  35.6139, 696.3857, 729.2228]], device='cuda:0')
# tensor([0.2501], device='cuda:0')
# tensor([2.], device='cuda:0')
#
# 0: 640x384 1 Casual_Top, 14.7ms
# Speed: 1.4ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.2942], device='cuda:0')
# data: tensor([[1.5455e+01, 3.5681e+01, 6.9846e+02, 7.2928e+02, 2.9418e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[356.9556, 382.4830, 683.0005, 693.6039]], device='cuda:0')
# xywhn: tensor([[0.4958, 0.2988, 0.9486, 0.5419]], device='cuda:0')
# xyxy: tensor([[ 15.4553,  35.6810, 698.4558, 729.2849]], device='cuda:0')
# xyxyn: tensor([[0.0215, 0.0279, 0.9701, 0.5698]], device='cuda:0')
# tensor([[ 15.4553,  35.6810, 698.4558, 729.2849]], device='cuda:0')
# tensor([0.2942], device='cuda:0')
# tensor([2.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.2923], device='cuda:0')
# data: tensor([[8.4764e+00, 5.0680e+02, 7.2000e+02, 1.2784e+03, 2.9233e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[364.2382, 892.6201, 711.5236, 771.6448]], device='cuda:0')
# xywhn: tensor([[0.5059, 0.6974, 0.9882, 0.6028]], device='cuda:0')
# xyxy: tensor([[   8.4764,  506.7977,  720.0000, 1278.4425]], device='cuda:0')
# xyxyn: tensor([[0.0118, 0.3959, 1.0000, 0.9988]], device='cuda:0')
# tensor([[   8.4764,  506.7977,  720.0000, 1278.4425]], device='cuda:0')
# tensor([0.2923], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 15.5ms
# Speed: 1.4ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.2766], device='cuda:0')
# data: tensor([[3.7422e+00, 5.0896e+02, 7.2000e+02, 1.2800e+03, 2.7657e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.8711, 894.4792, 716.2578, 771.0416]], device='cuda:0')
# xywhn: tensor([[0.5026, 0.6988, 0.9948, 0.6024]], device='cuda:0')
# xyxy: tensor([[   3.7422,  508.9584,  720.0000, 1280.0000]], device='cuda:0')
# xyxyn: tensor([[0.0052, 0.3976, 1.0000, 1.0000]], device='cuda:0')
# tensor([[   3.7422,  508.9584,  720.0000, 1280.0000]], device='cuda:0')
# tensor([0.2766], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 1 Corporate_Top, 15.6ms
# Speed: 1.3ms preprocess, 15.6ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1., 6.], device='cuda:0')
# conf: tensor([0.3230, 0.3217], device='cuda:0')
# data: tensor([[3.8724e+02, 1.1491e+03, 5.0799e+02, 1.2800e+03, 3.2300e-01, 1.0000e+00],
#         [3.9140e+00, 5.1053e+02, 7.2000e+02, 1.2793e+03, 3.2166e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 447.6143, 1214.5414,  120.7542,  130.9172],
#         [ 361.9570,  894.9351,  716.0860,  768.8115]], device='cuda:0')
# xywhn: tensor([[0.6217, 0.9489, 0.1677, 0.1023],
#         [0.5027, 0.6992, 0.9946, 0.6006]], device='cuda:0')
# xyxy: tensor([[ 387.2372, 1149.0828,  507.9913, 1280.0000],
#         [   3.9140,  510.5293,  720.0000, 1279.3408]], device='cuda:0')
# xyxyn: tensor([[0.5378, 0.8977, 0.7055, 1.0000],
#         [0.0054, 0.3989, 1.0000, 0.9995]], device='cuda:0')
# tensor([[ 387.2372, 1149.0828,  507.9913, 1280.0000],
#         [   3.9140,  510.5293,  720.0000, 1279.3408]], device='cuda:0')
# tensor([0.3230, 0.3217], device='cuda:0')
# tensor([1., 6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3123], device='cuda:0')
# data: tensor([[2.6766e+00, 5.1441e+02, 7.2000e+02, 1.2798e+03, 3.1233e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.3383, 897.1174, 717.3234, 765.4247]], device='cuda:0')
# xywhn: tensor([[0.5019, 0.7009, 0.9963, 0.5980]], device='cuda:0')
# xyxy: tensor([[   2.6766,  514.4050,  720.0000, 1279.8297]], device='cuda:0')
# xyxyn: tensor([[0.0037, 0.4019, 1.0000, 0.9999]], device='cuda:0')
# tensor([[   2.6766,  514.4050,  720.0000, 1279.8297]], device='cuda:0')
# tensor([0.3123], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.2600], device='cuda:0')
# data: tensor([[4.0869e+00, 5.2006e+02, 7.2000e+02, 1.2772e+03, 2.6001e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[362.0435, 898.6387, 715.9131, 757.1605]], device='cuda:0')
# xywhn: tensor([[0.5028, 0.7021, 0.9943, 0.5915]], device='cuda:0')
# xyxy: tensor([[   4.0869,  520.0585,  720.0000, 1277.2190]], device='cuda:0')
# xyxyn: tensor([[0.0057, 0.4063, 1.0000, 0.9978]], device='cuda:0')
# tensor([[   4.0869,  520.0585,  720.0000, 1277.2190]], device='cuda:0')
# tensor([0.2600], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.2510], device='cuda:0')
# data: tensor([[2.6332e+00, 5.2236e+02, 7.2000e+02, 1.2800e+03, 2.5102e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.3166, 901.1794, 717.3668, 757.6411]], device='cuda:0')
# xywhn: tensor([[0.5018, 0.7040, 0.9963, 0.5919]], device='cuda:0')
# xyxy: tensor([[   2.6332,  522.3589,  720.0000, 1280.0000]], device='cuda:0')
# xyxyn: tensor([[0.0037, 0.4081, 1.0000, 1.0000]], device='cuda:0')
# tensor([[   2.6332,  522.3589,  720.0000, 1280.0000]], device='cuda:0')
# tensor([0.2510], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 16.8ms
# Speed: 1.3ms preprocess, 16.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3648], device='cuda:0')
# data: tensor([[0.0000e+00, 5.3544e+02, 7.2000e+02, 1.2767e+03, 3.6482e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[360.0000, 906.0649, 720.0000, 741.2563]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.7079, 1.0000, 0.5791]], device='cuda:0')
# xyxy: tensor([[   0.0000,  535.4368,  720.0000, 1276.6931]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.4183, 1.0000, 0.9974]], device='cuda:0')
# tensor([[   0.0000,  535.4368,  720.0000, 1276.6931]], device='cuda:0')
# tensor([0.3648], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3183], device='cuda:0')
# data: tensor([[0.0000e+00, 5.3971e+02, 7.2000e+02, 1.2764e+03, 3.1831e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[360.0000, 908.0333, 720.0000, 736.6477]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.7094, 1.0000, 0.5755]], device='cuda:0')
# xyxy: tensor([[   0.0000,  539.7095,  720.0000, 1276.3572]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.4216, 1.0000, 0.9972]], device='cuda:0')
# tensor([[   0.0000,  539.7095,  720.0000, 1276.3572]], device='cuda:0')
# tensor([0.3183], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3402], device='cuda:0')
# data: tensor([[4.2732e+00, 5.3900e+02, 7.2000e+02, 1.2788e+03, 3.4025e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[362.1366, 908.9126, 715.7268, 739.8201]], device='cuda:0')
# xywhn: tensor([[0.5030, 0.7101, 0.9941, 0.5780]], device='cuda:0')
# xyxy: tensor([[   4.2732,  539.0026,  720.0000, 1278.8226]], device='cuda:0')
# xyxyn: tensor([[0.0059, 0.4211, 1.0000, 0.9991]], device='cuda:0')
# tensor([[   4.2732,  539.0026,  720.0000, 1278.8226]], device='cuda:0')
# tensor([0.3402], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.3ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3726], device='cuda:0')
# data: tensor([[1.1511e-01, 5.4864e+02, 7.2000e+02, 1.2767e+03, 3.7261e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[360.0576, 912.6708, 719.8849, 728.0651]], device='cuda:0')
# xywhn: tensor([[0.5001, 0.7130, 0.9998, 0.5688]], device='cuda:0')
# xyxy: tensor([[1.1511e-01, 5.4864e+02, 7.2000e+02, 1.2767e+03]], device='cuda:0')
# xyxyn: tensor([[1.5988e-04, 4.2862e-01, 1.0000e+00, 9.9742e-01]], device='cuda:0')
# tensor([[1.1511e-01, 5.4864e+02, 7.2000e+02, 1.2767e+03]], device='cuda:0')
# tensor([0.3726], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3580], device='cuda:0')
# data: tensor([[1.0712e+00, 5.5019e+02, 7.2000e+02, 1.2767e+03, 3.5798e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[360.5356, 913.4262, 718.9288, 726.4733]], device='cuda:0')
# xywhn: tensor([[0.5007, 0.7136, 0.9985, 0.5676]], device='cuda:0')
# xyxy: tensor([[1.0712e+00, 5.5019e+02, 7.2000e+02, 1.2767e+03]], device='cuda:0')
# xyxyn: tensor([[0.0015, 0.4298, 1.0000, 0.9974]], device='cuda:0')
# tensor([[1.0712e+00, 5.5019e+02, 7.2000e+02, 1.2767e+03]], device='cuda:0')
# tensor([0.3580], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 2.5ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3777], device='cuda:0')
# data: tensor([[3.3138e+00, 5.5458e+02, 7.2000e+02, 1.2770e+03, 3.7766e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.6569, 915.7860, 716.6862, 722.4026]], device='cuda:0')
# xywhn: tensor([[0.5023, 0.7155, 0.9954, 0.5644]], device='cuda:0')
# xyxy: tensor([[   3.3138,  554.5847,  720.0000, 1276.9873]], device='cuda:0')
# xyxyn: tensor([[0.0046, 0.4333, 1.0000, 0.9976]], device='cuda:0')
# tensor([[   3.3138,  554.5847,  720.0000, 1276.9873]], device='cuda:0')
# tensor([0.3777], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3499], device='cuda:0')
# data: tensor([[3.1023e+00, 5.6088e+02, 7.2000e+02, 1.2772e+03, 3.4994e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.5511, 919.0275, 716.8977, 716.3022]], device='cuda:0')
# xywhn: tensor([[0.5022, 0.7180, 0.9957, 0.5596]], device='cuda:0')
# xyxy: tensor([[   3.1023,  560.8763,  720.0000, 1277.1786]], device='cuda:0')
# xyxyn: tensor([[0.0043, 0.4382, 1.0000, 0.9978]], device='cuda:0')
# tensor([[   3.1023,  560.8763,  720.0000, 1277.1786]], device='cuda:0')
# tensor([0.3499], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3542], device='cuda:0')
# data: tensor([[3.4081e+00, 5.6092e+02, 7.2000e+02, 1.2773e+03, 3.5422e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[361.7040, 919.1213, 716.5919, 716.4014]], device='cuda:0')
# xywhn: tensor([[0.5024, 0.7181, 0.9953, 0.5597]], device='cuda:0')
# xyxy: tensor([[   3.4081,  560.9207,  720.0000, 1277.3220]], device='cuda:0')
# xyxyn: tensor([[0.0047, 0.4382, 1.0000, 0.9979]], device='cuda:0')
# tensor([[   3.4081,  560.9207,  720.0000, 1277.3220]], device='cuda:0')
# tensor([0.3542], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.8ms
# Speed: 1.6ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3540], device='cuda:0')
# data: tensor([[4.0139e+00, 5.6461e+02, 7.2000e+02, 1.2775e+03, 3.5400e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[362.0070, 921.0757, 715.9861, 712.9253]], device='cuda:0')
# xywhn: tensor([[0.5028, 0.7196, 0.9944, 0.5570]], device='cuda:0')
# xyxy: tensor([[   4.0139,  564.6130,  720.0000, 1277.5383]], device='cuda:0')
# xyxyn: tensor([[0.0056, 0.4411, 1.0000, 0.9981]], device='cuda:0')
# tensor([[   4.0139,  564.6130,  720.0000, 1277.5383]], device='cuda:0')
# tensor([0.3540], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3108], device='cuda:0')
# data: tensor([[5.0167e+00, 5.7996e+02, 7.2000e+02, 1.2792e+03, 3.1084e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[362.5084, 929.5862, 714.9833, 699.2434]], device='cuda:0')
# xywhn: tensor([[0.5035, 0.7262, 0.9930, 0.5463]], device='cuda:0')
# xyxy: tensor([[   5.0167,  579.9645,  720.0000, 1279.2079]], device='cuda:0')
# xyxyn: tensor([[0.0070, 0.4531, 1.0000, 0.9994]], device='cuda:0')
# tensor([[   5.0167,  579.9645,  720.0000, 1279.2079]], device='cuda:0')
# tensor([0.3108], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3673], device='cuda:0')
# data: tensor([[5.1450e+00, 5.8334e+02, 7.2000e+02, 1.2793e+03, 3.6730e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[362.5725, 931.3459, 714.8550, 696.0022]], device='cuda:0')
# xywhn: tensor([[0.5036, 0.7276, 0.9929, 0.5438]], device='cuda:0')
# xyxy: tensor([[   5.1450,  583.3448,  720.0000, 1279.3470]], device='cuda:0')
# xyxyn: tensor([[0.0071, 0.4557, 1.0000, 0.9995]], device='cuda:0')
# tensor([[   5.1450,  583.3448,  720.0000, 1279.3470]], device='cuda:0')
# tensor([0.3673], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.3523], device='cuda:0')
# data: tensor([[5.2898e+00, 5.8622e+02, 7.2000e+02, 1.2794e+03, 3.5232e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[362.6449, 932.7995, 714.7102, 693.1525]], device='cuda:0')
# xywhn: tensor([[0.5037, 0.7287, 0.9927, 0.5415]], device='cuda:0')
# xyxy: tensor([[   5.2898,  586.2233,  720.0000, 1279.3757]], device='cuda:0')
# xyxyn: tensor([[0.0073, 0.4580, 1.0000, 0.9995]], device='cuda:0')
# tensor([[   5.2898,  586.2233,  720.0000, 1279.3757]], device='cuda:0')
# tensor([0.3523], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4070], device='cuda:0')
# data: tensor([[5.2748e+00, 5.8847e+02, 7.2000e+02, 1.2794e+03, 4.0695e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[362.6374, 933.9522, 714.7252, 690.9618]], device='cuda:0')
# xywhn: tensor([[0.5037, 0.7297, 0.9927, 0.5398]], device='cuda:0')
# xyxy: tensor([[   5.2748,  588.4713,  720.0000, 1279.4331]], device='cuda:0')
# xyxyn: tensor([[0.0073, 0.4597, 1.0000, 0.9996]], device='cuda:0')
# tensor([[   5.2748,  588.4713,  720.0000, 1279.4331]], device='cuda:0')
# tensor([0.4070], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 1 Corporate_Top, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 1.], device='cuda:0')
# conf: tensor([0.3590, 0.2735], device='cuda:0')
# data: tensor([[6.0752e+00, 5.8520e+02, 7.2000e+02, 1.2795e+03, 3.5903e-01, 6.0000e+00],
#         [2.9011e+02, 1.1048e+03, 3.6565e+02, 1.2791e+03, 2.7354e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 363.0376,  932.3292,  713.9248,  694.2639],
#         [ 327.8804, 1191.9540,   75.5448,  174.2878]], device='cuda:0')
# xywhn: tensor([[0.5042, 0.7284, 0.9916, 0.5424],
#         [0.4554, 0.9312, 0.1049, 0.1362]], device='cuda:0')
# xyxy: tensor([[   6.0752,  585.1973,  720.0000, 1279.4612],
#         [ 290.1080, 1104.8101,  365.6528, 1279.0979]], device='cuda:0')
# xyxyn: tensor([[0.0084, 0.4572, 1.0000, 0.9996],
#         [0.4029, 0.8631, 0.5079, 0.9993]], device='cuda:0')
# tensor([[   6.0752,  585.1973,  720.0000, 1279.4612],
#         [ 290.1080, 1104.8101,  365.6528, 1279.0979]], device='cuda:0')
# tensor([0.3590, 0.2735], device='cuda:0')
# tensor([6., 1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 1 Corporate_Top, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 1.], device='cuda:0')
# conf: tensor([0.3827, 0.2892], device='cuda:0')
# data: tensor([[7.9836e+00, 5.8555e+02, 7.2000e+02, 1.2797e+03, 3.8271e-01, 6.0000e+00],
#         [2.8963e+02, 1.1201e+03, 3.6409e+02, 1.2793e+03, 2.8920e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 363.9918,  932.6151,  712.0164,  694.1379],
#         [ 326.8603, 1199.7009,   74.4646,  159.1250]], device='cuda:0')
# xywhn: tensor([[0.5055, 0.7286, 0.9889, 0.5423],
#         [0.4540, 0.9373, 0.1034, 0.1243]], device='cuda:0')
# xyxy: tensor([[   7.9836,  585.5461,  720.0000, 1279.6841],
#         [ 289.6280, 1120.1384,  364.0926, 1279.2634]], device='cuda:0')
# xyxyn: tensor([[0.0111, 0.4575, 1.0000, 0.9998],
#         [0.4023, 0.8751, 0.5057, 0.9994]], device='cuda:0')
# tensor([[   7.9836,  585.5461,  720.0000, 1279.6841],
#         [ 289.6280, 1120.1384,  364.0926, 1279.2634]], device='cuda:0')
# tensor([0.3827, 0.2892], device='cuda:0')
# tensor([6., 1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 1 Corporate_Top, 14.7ms
# Speed: 1.4ms preprocess, 14.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 1.], device='cuda:0')
# conf: tensor([0.3563, 0.3016], device='cuda:0')
# data: tensor([[6.6041e+00, 5.8223e+02, 7.2000e+02, 1.2796e+03, 3.5635e-01, 6.0000e+00],
#         [2.8995e+02, 1.0990e+03, 3.6456e+02, 1.2791e+03, 3.0163e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 363.3021,  930.9062,  713.3959,  697.3462],
#         [ 327.2513, 1189.0459,   74.6108,  180.0610]], device='cuda:0')
# xywhn: tensor([[0.5046, 0.7273, 0.9908, 0.5448],
#         [0.4545, 0.9289, 0.1036, 0.1407]], device='cuda:0')
# xyxy: tensor([[   6.6041,  582.2332,  720.0000, 1279.5793],
#         [ 289.9459, 1099.0154,  364.5568, 1279.0764]], device='cuda:0')
# xyxyn: tensor([[0.0092, 0.4549, 1.0000, 0.9997],
#         [0.4027, 0.8586, 0.5063, 0.9993]], device='cuda:0')
# tensor([[   6.6041,  582.2332,  720.0000, 1279.5793],
#         [ 289.9459, 1099.0154,  364.5568, 1279.0764]], device='cuda:0')
# tensor([0.3563, 0.3016], device='cuda:0')
# tensor([6., 1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 1 Corporate_Top, 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 1.], device='cuda:0')
# conf: tensor([0.3702, 0.3031], device='cuda:0')
# data: tensor([[5.0303e+00, 5.7994e+02, 7.2000e+02, 1.2797e+03, 3.7020e-01, 6.0000e+00],
#         [2.8972e+02, 1.0848e+03, 3.6424e+02, 1.2795e+03, 3.0311e-01, 1.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 362.5152,  929.7988,  714.9697,  699.7208],
#         [ 326.9795, 1182.1536,   74.5208,  194.7065]], device='cuda:0')
# xywhn: tensor([[0.5035, 0.7264, 0.9930, 0.5467],
#         [0.4541, 0.9236, 0.1035, 0.1521]], device='cuda:0')
# xyxy: tensor([[   5.0303,  579.9384,  720.0000, 1279.6592],
#         [ 289.7191, 1084.8003,  364.2399, 1279.5068]], device='cuda:0')
# xyxyn: tensor([[0.0070, 0.4531, 1.0000, 0.9997],
#         [0.4024, 0.8475, 0.5059, 0.9996]], device='cuda:0')
# tensor([[   5.0303,  579.9384,  720.0000, 1279.6592],
#         [ 289.7191, 1084.8003,  364.2399, 1279.5068]], device='cuda:0')
# tensor([0.3702, 0.3031], device='cuda:0')
# tensor([6., 1.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 1 Casual_Top, 1 Corporate_Top, 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1., 2., 6.], device='cuda:0')
# conf: tensor([0.4524, 0.3121, 0.2854], device='cuda:0')
# data: tensor([[2.8855e+02, 1.0800e+03, 3.6208e+02, 1.2795e+03, 4.5239e-01, 1.0000e+00],
#         [1.0777e+01, 5.6480e+02, 7.2000e+02, 1.2800e+03, 3.1213e-01, 2.0000e+00],
#         [4.8054e+00, 5.7752e+02, 7.1955e+02, 1.2794e+03, 2.8542e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([3, 6])
# xywh: tensor([[ 325.3181, 1179.7560,   73.5278,  199.5247],
#         [ 365.3884,  922.3976,  709.2232,  715.2047],
#         [ 362.1755,  928.4373,  714.7401,  701.8286]], device='cuda:0')
# xywhn: tensor([[0.4518, 0.9217, 0.1021, 0.1559],
#         [0.5075, 0.7206, 0.9850, 0.5588],
#         [0.5030, 0.7253, 0.9927, 0.5483]], device='cuda:0')
# xyxy: tensor([[ 288.5542, 1079.9937,  362.0819, 1279.5183],
#         [  10.7768,  564.7953,  720.0000, 1280.0000],
#         [   4.8054,  577.5229,  719.5455, 1279.3516]], device='cuda:0')
# xyxyn: tensor([[0.4008, 0.8437, 0.5029, 0.9996],
#         [0.0150, 0.4412, 1.0000, 1.0000],
#         [0.0067, 0.4512, 0.9994, 0.9995]], device='cuda:0')
# tensor([[ 288.5542, 1079.9937,  362.0819, 1279.5183],
#         [  10.7768,  564.7953,  720.0000, 1280.0000],
#         [   4.8054,  577.5229,  719.5455, 1279.3516]], device='cuda:0')
# tensor([0.4524, 0.3121, 0.2854], device='cuda:0')
# tensor([1., 2., 6.], device='cuda:0')
#
# 0: 640x384 1 Casual_Sneakers, 1 Casual_Top, 1 Corporate_Top, 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1., 6., 2.], device='cuda:0')
# conf: tensor([0.4841, 0.3241, 0.2560], device='cuda:0')
# data: tensor([[2.8960e+02, 1.0744e+03, 3.6236e+02, 1.2796e+03, 4.8407e-01, 1.0000e+00],
#         [3.2955e+00, 5.7194e+02, 7.1672e+02, 1.2785e+03, 3.2405e-01, 6.0000e+00],
#         [1.1725e+00, 5.6280e+02, 7.2000e+02, 1.2780e+03, 2.5598e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([3, 6])
# xywh: tensor([[ 325.9760, 1176.9868,   72.7599,  205.1455],
#         [ 360.0063,  925.2318,  713.4216,  706.5911],
#         [ 360.5862,  920.3857,  718.8275,  715.1652]], device='cuda:0')
# xywhn: tensor([[0.4527, 0.9195, 0.1011, 0.1603],
#         [0.5000, 0.7228, 0.9909, 0.5520],
#         [0.5008, 0.7191, 0.9984, 0.5587]], device='cuda:0')
# xyxy: tensor([[2.8960e+02, 1.0744e+03, 3.6236e+02, 1.2796e+03],
#         [3.2955e+00, 5.7194e+02, 7.1672e+02, 1.2785e+03],
#         [1.1725e+00, 5.6280e+02, 7.2000e+02, 1.2780e+03]], device='cuda:0')
# xyxyn: tensor([[0.4022, 0.8394, 0.5033, 0.9997],
#         [0.0046, 0.4468, 0.9954, 0.9988],
#         [0.0016, 0.4397, 1.0000, 0.9984]], device='cuda:0')
# tensor([[2.8960e+02, 1.0744e+03, 3.6236e+02, 1.2796e+03],
#         [3.2955e+00, 5.7194e+02, 7.1672e+02, 1.2785e+03],
#         [1.1725e+00, 5.6280e+02, 7.2000e+02, 1.2780e+03]], device='cuda:0')
# tensor([0.4841, 0.3241, 0.2560], device='cuda:0')
# tensor([1., 6., 2.], device='cuda:0')
#
# 0: 640x384 1 Casual_Top, 1 Corporate_Top, 14.7ms
# Speed: 1.6ms preprocess, 14.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 6.], device='cuda:0')
# conf: tensor([0.4118, 0.3975], device='cuda:0')
# data: tensor([[6.7134e+01, 3.5810e+02, 7.1635e+02, 8.8537e+02, 4.1180e-01, 2.0000e+00],
#         [1.7345e+02, 8.5260e+02, 6.8151e+02, 1.2772e+03, 3.9748e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 391.7440,  621.7343,  649.2203,  527.2706],
#         [ 427.4838, 1064.9150,  508.0590,  424.6267]], device='cuda:0')
# xywhn: tensor([[0.5441, 0.4857, 0.9017, 0.4119],
#         [0.5937, 0.8320, 0.7056, 0.3317]], device='cuda:0')
# xyxy: tensor([[  67.1338,  358.0989,  716.3541,  885.3696],
#         [ 173.4543,  852.6017,  681.5133, 1277.2284]], device='cuda:0')
# xyxyn: tensor([[0.0932, 0.2798, 0.9949, 0.6917],
#         [0.2409, 0.6661, 0.9465, 0.9978]], device='cuda:0')
# tensor([[  67.1338,  358.0989,  716.3541,  885.3696],
#         [ 173.4543,  852.6017,  681.5133, 1277.2284]], device='cuda:0')
# tensor([0.4118, 0.3975], device='cuda:0')
# tensor([2., 6.], device='cuda:0')
#
# 0: 640x384 1 Casual_Top, 1 Corporate_Top, 14.7ms
# Speed: 1.2ms preprocess, 14.7ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 6.], device='cuda:0')
# conf: tensor([0.4433, 0.3878], device='cuda:0')
# data: tensor([[7.2596e+01, 3.5748e+02, 7.1470e+02, 8.8617e+02, 4.4332e-01, 2.0000e+00],
#         [1.7004e+02, 8.5478e+02, 6.8695e+02, 1.2755e+03, 3.8778e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([2, 6])
# xywh: tensor([[ 393.6474,  621.8261,  642.1020,  528.6837],
#         [ 428.4925, 1065.1168,  516.9108,  420.6724]], device='cuda:0')
# xywhn: tensor([[0.5467, 0.4858, 0.8918, 0.4130],
#         [0.5951, 0.8321, 0.7179, 0.3287]], device='cuda:0')
# xyxy: tensor([[  72.5964,  357.4843,  714.6984,  886.1680],
#         [ 170.0371,  854.7806,  686.9479, 1275.4530]], device='cuda:0')
# xyxyn: tensor([[0.1008, 0.2793, 0.9926, 0.6923],
#         [0.2362, 0.6678, 0.9541, 0.9964]], device='cuda:0')
# tensor([[  72.5964,  357.4843,  714.6984,  886.1680],
#         [ 170.0371,  854.7806,  686.9479, 1275.4530]], device='cuda:0')
# tensor([0.4433, 0.3878], device='cuda:0')
# tensor([2., 6.], device='cuda:0')
#
# 0: 640x384 1 Casual_Top, 14.9ms
# Speed: 1.4ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.4225], device='cuda:0')
# data: tensor([[4.5177e+01, 3.5783e+02, 7.1564e+02, 8.8944e+02, 4.2251e-01, 2.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[380.4089, 623.6342, 670.4640, 531.6079]], device='cuda:0')
# xywhn: tensor([[0.5283, 0.4872, 0.9312, 0.4153]], device='cuda:0')
# xyxy: tensor([[ 45.1769, 357.8302, 715.6409, 889.4381]], device='cuda:0')
# xyxyn: tensor([[0.0627, 0.2796, 0.9939, 0.6949]], device='cuda:0')
# tensor([[ 45.1769, 357.8302, 715.6409, 889.4381]], device='cuda:0')
# tensor([0.4225], device='cuda:0')
# tensor([2.], device='cuda:0')
#
# 0: 640x384 1 Casual_Top, 1 Corporate_Top, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 6.], device='cuda:0')
# conf: tensor([0.3471, 0.2603], device='cuda:0')
# data: tensor([[6.1415e+01, 3.5754e+02, 7.1369e+02, 8.9121e+02, 3.4710e-01, 2.0000e+00],
# ...
# xyxy: tensor([[   0.0000,    1.5940,  720.0000, 1263.9583]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5940,  720.0000, 1263.9583]], device='cuda:0')
# tensor([0.4143], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.4ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4136], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5930e+00, 7.2000e+02, 1.2640e+03, 4.1365e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7854,  720.0000, 1262.3848]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5930,  720.0000, 1263.9778]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5930,  720.0000, 1263.9778]], device='cuda:0')
# tensor([0.4136], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.3ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4137], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5885e+00, 7.2000e+02, 1.2640e+03, 4.1369e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7761,  720.0000, 1262.3751]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5885,  720.0000, 1263.9636]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5885,  720.0000, 1263.9636]], device='cuda:0')
# tensor([0.4137], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.4ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4137], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5908e+00, 7.2000e+02, 1.2640e+03, 4.1373e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7834,  720.0000, 1262.3853]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5908,  720.0000, 1263.9761]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5908,  720.0000, 1263.9761]], device='cuda:0')
# tensor([0.4137], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4145], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5908e+00, 7.2000e+02, 1.2640e+03, 4.1454e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7804,  720.0000, 1262.3792]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5908,  720.0000, 1263.9700]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5908,  720.0000, 1263.9700]], device='cuda:0')
# tensor([0.4145], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.8ms
# Speed: 1.8ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4143], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5923e+00, 7.2000e+02, 1.2640e+03, 4.1426e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7812,  720.0000, 1262.3779]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5923,  720.0000, 1263.9702]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5923,  720.0000, 1263.9702]], device='cuda:0')
# tensor([0.4143], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.8ms
# Speed: 1.3ms preprocess, 14.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4145], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5876e+00, 7.2000e+02, 1.2640e+03, 4.1449e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7759,  720.0000, 1262.3765]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5876,  720.0000, 1263.9641]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5876,  720.0000, 1263.9641]], device='cuda:0')
# tensor([0.4145], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.8ms
# Speed: 1.7ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4145], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5880e+00, 7.2000e+02, 1.2640e+03, 4.1452e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7775,  720.0000, 1262.3789]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5880,  720.0000, 1263.9669]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5880,  720.0000, 1263.9669]], device='cuda:0')
# tensor([0.4145], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4148], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5913e+00, 7.2000e+02, 1.2640e+03, 4.1482e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7725,  720.0000, 1262.3624]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5913,  720.0000, 1263.9537]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5913,  720.0000, 1263.9537]], device='cuda:0')
# tensor([0.4148], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4147], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5873e+00, 7.2000e+02, 1.2640e+03, 4.1471e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7742,  720.0000, 1262.3739]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5873,  720.0000, 1263.9612]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5873,  720.0000, 1263.9612]], device='cuda:0')
# tensor([0.4147], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.4ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4145], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5837e+00, 7.2000e+02, 1.2640e+03, 4.1448e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7748,  720.0000, 1262.3821]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5837,  720.0000, 1263.9658]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5837,  720.0000, 1263.9658]], device='cuda:0')
# tensor([0.4145], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 16.0ms
# Speed: 1.4ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4148], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5850e+00, 7.2000e+02, 1.2640e+03, 4.1477e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7708,  720.0000, 1262.3716]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5850,  720.0000, 1263.9565]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5850,  720.0000, 1263.9565]], device='cuda:0')
# tensor([0.4148], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4148], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5813e+00, 7.2000e+02, 1.2640e+03, 4.1479e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7699,  720.0000, 1262.3772]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5813,  720.0000, 1263.9585]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5813,  720.0000, 1263.9585]], device='cuda:0')
# tensor([0.4148], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.4ms preprocess, 14.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4147], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5813e+00, 7.2000e+02, 1.2640e+03, 4.1469e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7697,  720.0000, 1262.3767]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5813,  720.0000, 1263.9580]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5813,  720.0000, 1263.9580]], device='cuda:0')
# tensor([0.4147], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 27.1ms
# Speed: 3.1ms preprocess, 27.1ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4148], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5840e+00, 7.2000e+02, 1.2640e+03, 4.1479e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7722,  720.0000, 1262.3765]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5840,  720.0000, 1263.9604]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5840,  720.0000, 1263.9604]], device='cuda:0')
# tensor([0.4148], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.4ms preprocess, 14.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4148], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5844e+00, 7.2000e+02, 1.2640e+03, 4.1484e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7710,  720.0000, 1262.3733]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5844,  720.0000, 1263.9576]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5844,  720.0000, 1263.9576]], device='cuda:0')
# tensor([0.4148], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4148], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5818e+00, 7.2000e+02, 1.2640e+03, 4.1479e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7706,  720.0000, 1262.3777]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5818,  720.0000, 1263.9595]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5818,  720.0000, 1263.9595]], device='cuda:0')
# tensor([0.4148], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 14.7ms
# Speed: 1.4ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4146], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5841e+00, 7.2000e+02, 1.2640e+03, 4.1456e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7740,  720.0000, 1262.3799]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5841,  720.0000, 1263.9640]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5841,  720.0000, 1263.9640]], device='cuda:0')
# tensor([0.4146], device='cuda:0')
# tensor([6.], device='cuda:0')
#
# 0: 640x384 1 Corporate_Top, 16.8ms
# Speed: 1.5ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.], device='cuda:0')
# conf: tensor([0.4146], device='cuda:0')
# data: tensor([[0.0000e+00, 1.5861e+00, 7.2000e+02, 1.2640e+03, 4.1457e-01, 6.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1280, 720)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 360.0000,  632.7722,  720.0000, 1262.3723]], device='cuda:0')
# xywhn: tensor([[0.5000, 0.4944, 1.0000, 0.9862]], device='cuda:0')
# xyxy: tensor([[   0.0000,    1.5861,  720.0000, 1263.9584]], device='cuda:0')
# xyxyn: tensor([[0.0000, 0.0012, 1.0000, 0.9875]], device='cuda:0')
# tensor([[   0.0000,    1.5861,  720.0000, 1263.9584]], device='cuda:0')
# tensor([0.4146], device='cuda:0')
# tensor([6.], device='cuda:0')

# %%
video_path = "C:/Users/isatyamks/Repositories/Stealth/flickd/data/videos/2025-05-31_14-01-37_UTC.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():

    print(f"[!] Failed to open video at: {video_path}")
    return
# Out:
#   Cell In[17], line 6
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
import os

video_path = "../data/videos/2025-05-31_14-01-37_UTC.mp4"
abs_path = os.path.abspath(video_path)

print("Resolved path:", abs_path)
print("File exists:", os.path.exists(video_path))
# Out:
# Resolved path: c:\Users\isatyamks\Repositories\Stealth\flickd\data\videos\2025-05-31_14-01-37_UTC.mp4
# File exists: True
